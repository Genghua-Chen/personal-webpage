# %%
https://www.linkedin.com/jobs/search-results/?currentJobId=4281663983&distance=25&eBP=BUDGET_EXHAUSTED_JOB&f_TPR=r86400&geoId=90000070&keywords=Machine%20learning&origin=SEMANTIC_SEARCH_HISTORY&refId=aKij4IIm6LlnZ%2F4%2FPHT7Pg%3D%3D&trackingId=npvZaaYx8KfeJ0%2BgUFNnuw%3D%3D

# %%
a = """ 
Conclusion
""".strip()


b = a.lower().replace(" ", "-")
print(f"- [{a}](#{b})")
# Out:
# - [Conclusion](#conclusion)

# %%
sorted("fsada")
# Out:
# ['a', 'a', 'd', 'f', 's']

# %%
name = "Ilya"
company = "Spotify"


msg = f"""
Hi {name}, 

This is Caine. I came across your profile while exploring ML/data roles in {company}. I’m currently working as an ML + data engineer (LLMs, pipelines, recsys) and really admire the work your team is doing. 
Would love to hear how your experience has been at {company} or what you think makes someone successful there. 
""".strip()
print(msg)
# Out:
# Hi Ilya,
#
# This is Caine. I came across your profile while exploring ML/data roles in Spotify. I’m currently working as an ML + data engineer (LLMs, pipelines, recsys) and really admire the work your team is doing.
# Would love to hear how your experience has been at Spotify or what you think makes someone successful there.

# %%
name = "Ilya"
company = "Spotify"


Research Assistant
Research Assistant
Columbia Engineering
msg = f"""
Hi {name}, 

I’m an ML + data engineer with 3+ YOE in production systems (LLMs, CTR optimization, quantized inference) and I’m exploring new roles. I’m really interested in what {company} is building — would love to connect and learn if there are any teams currently hiring for someone with my background.
""".strip()
print(msg)

# %%
msg = f"""
thanks for connecting! I’m an ML + data engineer with 3+ years of experience working on production systems — including LLM optimization, quantized inference, and CTR-focused recommendation engines. I’m currently exploring new opportunities and really admire what {company} is building.

If you're aware of any teams hiring someone with my background, I’d really appreciate the chance to apply — and would be grateful if you'd consider a referral. Happy to send over my resume and a specific role link. Thanks again, and no pressure at all!
""".strip()
print(msg)

# %%
name = "Vincent"
msg = f"""
Hi {name}, 

Thanks for connecting! I’m an ML + data engineer with 3+ years of experience working on production systems, including LLM optimization, quantized inference, and CTR-focused recommendation engines. I’m currently exploring new opportunities.

If you're aware of any teams hiring someone with my background, I’d really appreciate the chance to apply, and would be grateful if you'd consider a referral. Happy to send over my resume and a specific role link. Thanks again, and no pressure at all!
""".strip()
print(msg)
# Out:
# Hi Vincent,
#
# Thanks for connecting! I’m an ML + data engineer with 3+ years of experience working on production systems, including LLM optimization, quantized inference, and CTR-focused recommendation engines. I’m currently exploring new opportunities.
#
# If you're aware of any teams hiring someone with my background, I’d really appreciate the chance to apply, and would be grateful if you'd consider a referral. Happy to send over my resume and a specific role link. Thanks again, and no pressure at all!

# %%
name = "Dongqi"
job = "AI Infra Engineer"
company = "Perplexity"

msg = f"""
Hi {name}, 

I’m an ML/data engineer with 3+ YOE in production ML pipelines, LLM inference, and recsys. 
I saw an opening for {job} at {company} that seems like a great fit, and I’d love to ask if you’d be open to referring me. Happy to send over my resume if so and totally understand if not.


""".strip()
print(msg)
# Out:
# Hi Dongqi,
#
# I’m an ML/data engineer with 3+ YOE in production ML pipelines, LLM inference, and recsys.
# I saw an opening for AI Infra Engineer at Perplexity that seems like a great fit, and I’d love to ask if you’d be open to referring me. Happy to send over my resume and job link if so and totally understand if not.
